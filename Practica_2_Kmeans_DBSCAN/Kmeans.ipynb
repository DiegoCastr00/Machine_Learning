# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def K_Means(data, columns):
    X_scaled = data[columns].values

    max_clusters = 4
    inertia_values = []

    def calculate_distances(X, centroids):
        num_points = X.shape[0]
        num_clusters = centroids.shape[0]
        distances = np.zeros((num_points, num_clusters))
        
        for i in range(num_clusters):
            centroid = centroids[i]
            squared_distances = np.sum((X - centroid) ** 2, axis=1)
            distances[:, i] = np.sqrt(squared_distances)
        
        return distances

    def update_centroids(X, labels, num_clusters):
        new_centroids = np.zeros((num_clusters, X.shape[1]))
        for i in range(num_clusters):
            cluster_points = X[labels == i]
            if len(cluster_points) > 0:
                new_centroids[i] = np.mean(cluster_points, axis=0)
        return new_centroids

    def calculate_inertia(X, labels, centroids):
        inertia = 0
        for i in range(len(centroids)):
            cluster_points = X[labels == i]
            squared_distances = np.sum((cluster_points - centroids[i]) ** 2)
            inertia += squared_distances
        return inertia

    def Status(data, columns):
        color_map = {'photo': 'blue', 'video': 'red', 'link': 'green', 'status': 'black'}
        fig, ax = plt.subplots(figsize=(10, 6))
        for status_type, group in data.groupby('status_type'):
            ax.scatter(group[columns[0]], group[columns[1]], label=status_type, c=color_map.get(status_type, 'gray'))
        ax.set_xlabel(columns[0])
        ax.set_ylabel(columns[1])
        ax.set_title('Status')
        ax.legend()
        plt.show()
    def extract_year(date_str):
        parts = date_str.split('/')
        if len(parts) >= 3:
            return int(parts[2].split()[0])
        else:
            return None

    def published(data, columns):
        data['Year'] = data['status_published'].apply(extract_year)
        unique_years = data['Year'].unique()
        color_map = plt.cm.get_cmap('viridis', len(unique_years))
        colors = [color_map(i / len(unique_years)) for i in range(len(unique_years))]
        plt.figure(figsize=(10, 6))
        for year, color in zip(unique_years, colors):
            subset = data[data['Year'] == year]
            plt.scatter(subset[columns[0]], subset[columns[1]], label=f'Year {year}', c=[color])

        plt.xlabel(columns[0])
        plt.ylabel(columns[1])
        plt.title('Color por Año')
        plt.legend()
        plt.show()
     
    Status(data, columns) 
    published(data, columns)

    fig, axs = plt.subplots(5, 2, figsize=(12, 20))
    fig.subplots_adjust(hspace=0.5)

    for num_clusters in range(1, max_clusters + 1):
        np.random.seed(0)
        centroids = X_scaled[np.random.choice(X_scaled.shape[0], num_clusters, replace=False)]
        max_iters = 100

        for _ in range(max_iters):
            distances = calculate_distances(X_scaled, centroids)
            labels = np.argmin(distances, axis=1)
            new_centroids = update_centroids(X_scaled, labels, num_clusters)

            if np.all(centroids == new_centroids):
                break
            centroids = new_centroids

        inertia = calculate_inertia(X_scaled, labels, centroids)
        inertia_values.append(inertia)

        # Calcular las coordenadas de los subplots
        row = (num_clusters - 1) // 2
        col = (num_clusters - 1) % 2
        
        axs[row, col].scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='rainbow')
        axs[row, col].scatter(centroids[:, 0], centroids[:, 1], s=100, c='black', label='Centroides')
        axs[row, col].set_title(f'Clusters: {num_clusters}\nInercia: {inertia:.2f}')
        axs[row, col].legend()

    for ax in axs.flat:
        ax.set(xlabel=columns[0], ylabel=columns[1])
        
        # Elimina plots vacíos 
    for i in range(max_clusters, 10):
        fig.delaxes(axs.flatten()[i])

    # Crear gráfico del método del codo
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_clusters + 1), inertia_values, marker='o', linestyle='-')
    plt.xlabel('Número de Clusters')
    plt.ylabel('Inercia')
    plt.title(f'Método del Codo para Encontrar el Número Óptimo de Clusters ({columns[0]} vs {columns[1]})')
    plt.grid(True)

    plt.show()

# %%
archivo_csv = 'live.csv'  
data = pd.read_csv(archivo_csv)
columnas_a_eliminar = ['Column1', 'Column2', 'Column3', 'Column4']
data = data.drop(columns=columnas_a_eliminar)

K_Means(data,columns=['num_likes', 'num_reactions'] )
# Out:
# C:\Users\Khoss\AppData\Local\Temp\ipykernel_10168\293602314.py:55: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = plt.cm.get_cmap('viridis', len(unique_years))

# %%
def K_Means3D(data, columns):
    X = data[columns].values
    max_clusters = 4
    inertia_values = []
    def calculate_distances(X, centroids):
        num_points = X.shape[0]
        num_clusters = centroids.shape[0]
        distances = np.zeros((num_points, num_clusters))
        for i in range(num_clusters):
            centroid = centroids[i]
            squared_distances = np.sum((X - centroid) ** 2, axis=1)
            distances[:, i] = np.sqrt(squared_distances)  
        return distances
    def update_centroids(X, labels, num_clusters):
        new_centroids = np.zeros((num_clusters, X.shape[1]))
        for i in range(num_clusters):
            cluster_points = X[labels == i]
            if len(cluster_points) > 0:
                new_centroids[i] = np.mean(cluster_points, axis=0)
        return new_centroids
    def calculate_inertia(X, labels, centroids):
        inertia = 0
        for i in range(len(centroids)):
            cluster_points = X[labels == i]
            squared_distances = np.sum((cluster_points - centroids[i]) ** 2)
            inertia += squared_distances
        return inertia
    fig = plt.figure(figsize=(12, 22))
    for num_clusters in range(1, max_clusters + 1):
        np.random.seed(0)
        centroids = X[np.random.choice(X.shape[0], num_clusters, replace=False)]
        max_iters = 100
        for _ in range(max_iters):
            distances = calculate_distances(X, centroids)
            labels = np.argmin(distances, axis=1)
            new_centroids = update_centroids(X, labels, num_clusters)
            if np.all(centroids == new_centroids):
                break
            centroids = new_centroids
        inertia = calculate_inertia(X, labels, centroids)
        inertia_values.append(inertia)
        ax = fig.add_subplot(5, 2, num_clusters, projection='3d')
        ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels, cmap='rainbow')
        ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], s=200, c='black', label='Centroides')
        ax.set_title(f'Clusters: {num_clusters}\nInercia: {inertia:.2f}')
        ax.legend()
        ax.set_xlabel(columns[0])
        ax.set_ylabel(columns[1])
        ax.set_zlabel(columns[2])
    plt.tight_layout()
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_clusters + 1), inertia_values, marker='o', linestyle='-')
    plt.xlabel('Número de Clusters')
    plt.ylabel('Inercia')
    plt.title(f'Método del Codo para Encontrar el Número Óptimo de Clusters ({columns[0]}, {columns[1]}, {columns[2]})')
    plt.grid(True)
    plt.show()

columns = ['num_reactions', 'num_comments', 'num_shares']
K_Means3D(data, columns)
